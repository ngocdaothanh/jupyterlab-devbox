# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Create arrays

# %%
x = np.linspace(-4, 4, 20)
y = np.sin(x)

# %% [markdown]
# ## Line chart

# %%
plt.plot(x, y)
plt.grid(True)
plt.gca().set_aspect('equal')

# %% [markdown]
# ## Points

# %%
plt.scatter(x, y, marker="+", color='red')

# %% [markdown]
# ## Bar chart

# %%
labels = ['A', 'B', 'C', 'D']
values = [10, 24, 36, 18]
plt.bar(labels, values)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ## Histogram

# %%
data = np.random.randn(1000)
plt.hist(data, bins=30)
# Out:
# (array([ 5.,  2.,  4.,  8., 10., 12., 22., 21., 24., 37., 49., 63., 66.,
#         65., 71., 74., 82., 81., 62., 54., 50., 35., 30., 21., 16., 14.,
#         12.,  7.,  1.,  2.]),
#  array([-2.96989031, -2.77904484, -2.58819936, -2.39735388, -2.2065084 ,
#         -2.01566292, -1.82481745, -1.63397197, -1.44312649, -1.25228101,
#         -1.06143553, -0.87059006, -0.67974458, -0.4888991 , -0.29805362,
#         -0.10720814,  0.08363733,  0.27448281,  0.46532829,  0.65617377,
#          0.84701925,  1.03786472,  1.2287102 ,  1.41955568,  1.61040116,
#          1.80124664,  1.99209212,  2.18293759,  2.37378307,  2.56462855,
#          2.75547403]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# ## Pie chart

# %%
labels = ['Táo', 'Chuối', 'Cam', 'Nho']
sizes = [25, 30, 20, 25]
plt.pie(sizes, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x10e227e00>,
#   <matplotlib.patches.Wedge at 0x10e631810>,
#   <matplotlib.patches.Wedge at 0x10e631a90>,
#   <matplotlib.patches.Wedge at 0x10e631d10>],
#  [Text(0.777817442305461, 0.7778174763049434, 'Táo'),
#   Text(-0.8899187390319623, 0.6465637152823859, 'Chuối'),
#   Text(-0.6465639946425109, -0.8899185360649138, 'Cam'),
#   Text(0.7778177173879477, -0.7778172012223713, 'Nho')])

# %% [markdown]
# ## Heatmap

# %%
data = np.random.rand(6, 6)
sns.heatmap(data, annot=True)
# Out:
# <Axes: >
